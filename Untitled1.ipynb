# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pt

df = pd.read_csv("IPL Matches 2008-2020.csv")

# %%
df.sort_values(by=["result_margin"], inplace=True)
features = df[["result_margin","team1"]]
pt.plot(features["result_margin"],features["team1"])
pt.show()

# %%
pip install twilio
# Out:
# ...
#   Created wheel for twilio: filename=twilio-6.57.0-py2.py3-none-any.whl size=1267958 sha256=e2f4aa5f7cdc2271d68b07e5c29a2c17e8291c6ed47cd294c078d10ae6d0e1f8
#   Stored in directory: C:\Users\admin\AppData\Local\pip\Cache\wheels\c4\b8\37\e11490817fc37c7bf3ce9a20196f43f86e4a241301134f40d2
# Successfully built twilio
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install flask
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("IPL Matches 2008-2020.csv")
labels = df["winner"]
features = df[["team2","team1"]]
X_train,X_test,Y_train,Y_test = train_test_split(features,labels,train_size=0.7,test_size=0.3)
X_test
# Out:
#                            team2                        team1
# 682             Rajasthan Royals               Mumbai Indians
# 648             Delhi Daredevils        Kolkata Knight Riders
# 325             Rajasthan Royals             Delhi Daredevils
# 480  Royal Challengers Bangalore             Rajasthan Royals
# 477        Kolkata Knight Riders          Sunrisers Hyderabad
# ..                           ...                          ...
# 150             Rajasthan Royals              Deccan Chargers
# 446  Royal Challengers Bangalore        Kolkata Knight Riders
# 208                Pune Warriors  Royal Challengers Bangalore
# 491          Chennai Super Kings          Sunrisers Hyderabad
# 715               Delhi Capitals  Royal Challengers Bangalore
#
# [245 rows x 2 columns]

# %%
from sklearn.metrics import confusion_matrix, classification_report,  accuracy_score
from sklearn import tree, preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np
from twilio.twiml.messaging_response import MessagingResponse
from flask import Flask, request

# %%
df.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold  #For K-fold cross validation
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %%
df.team1==winner.head()
